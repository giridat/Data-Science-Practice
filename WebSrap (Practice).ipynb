# %%
from bs4 import BeautifulSoup as soup
import requests
import pandas as pd
url="https://www.goibibo.com/hotels/hotels-in-shimla-ct/"
header = { "user-agent" : "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.103 Safari/537.36",
    "referer" :"www.google.com"}
r=requests.request("GET", url, headers = header)
r.status_code
html=r.content
page_html=r.text.strip()
page_soup = soup(page_html, "html.parser")
page_soup
# Out:
# <!DOCTYPE html>
# ...

# %%
print(page_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <title>
#    Hotels in Shimla - Book 846 Shimla Hotels with 𝘂𝗽𝘁𝗼 𝟱𝟬% off @ ₹296
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="Best Shimla Hotels with upto 50% off from Goibibo. Check 58056 reviews and 39222 photos for 846  Shimla Hotels. Use coupon code GETSETGO and grab best deals starting from  @ ₹296 on Shimla online hotel booking. ✔ Lowest Price Guarantee ✔ Fastest Booking ✔ Instant Refund" name="description"/>
#   <meta content="width=device-width,initial-scale=1.0, maximum-scale=5.0, user-scalable=0" name="viewport"/>
#   <meta content="hotels in Shimla, best hotels in Shimla, Shimla hotels, Shimla hotel booking, Shimla hotel price, Shimla hotel deals, book Shimla hotels, goibibo Shimla hotels" name="keywords"/>
# ...

# %%
page_soup.title.string
# Out:
# 'Hotels in Shimla - Book 846 Shimla Hotels with 𝘂𝗽𝘁𝗼 𝟱𝟬% off @ ₹296'

# %%
hotel_details=page_soup.find_all("div",{"class":"hotel-tile-srp-container-content-container"})
hotel_details[0]
len(hotel_details)
# Out:
# 10

# %%
print(hotel_details[0].prettify())
# Out:
# <div class="hotel-tile-srp-container-content-container">
#  <ul class="hotel-content-container-top-hinged-list">
#   <li>
#    <div style="display: inline-block;">
#     <i class="icon-star3" style="font-size: 15px; color: #fdba00;">
#     </i>
#     <i class="icon-star3" style="font-size: 15px; color: #fdba00;">
#     </i>
#     <i class="icon-star3" style="font-size: 15px; color: #fdba00;">
#     </i>
#     <i class="icon-star3" style="font-size: 15px; color: #fdba00;">
#     </i>
#     <span style="padding: 2px; border: 1px solid #e5edf6; border-radius: 2px; margin-left: 5px; color: #4f525a">
#      RESORT
#     </span>
#    </div>
#    <div style="float: right; margin-right:8px; margin-top:3px;">
#     <span>
#      179 reviews
#     </span>
#     <span style="padding: 4px; background-color: #7ccf50; color: white; border-radius: 2px; margin-left: 5px;">
#      4.6/5
#     </span>
#    </div>
#   </li>
#   <li>
# ...

# %%
rating=hotel_details[0].find_all("span")[2].text
rating
# Out:
# '4.6/5'

# %%
location=hotel_details[0].find_all("li")[2].text
location
# Out:
# 'Mashobra B, Shimla'

# %%
name=hotel_details[0].find_all("li")[1].text
name
# Out:
# 'Summit Thistle Villa Resort & Spa'

# %%
recommendation=hotel_details[0].find_all("span")[3].text
recommendation
# Out:
# '95% Guests recommend this hotel'

# %%
type_=hotel_details[0].find_all("span")[0].text
type_
# Out:
# 'RESORT'

# %%
filename= "Hotels.csv"

f=open(filename,'w')

headers = "Name, Location, Recommendation, Rating, Type\n  "

f.write(headers)


c=0
while c<len(hotel_details):
    Name = hotel_details[c].find_all("li")[1].text 
    
    Location = hotel_details[c].find_all("li")[2].text
   
    Recommendation = hotel_details[c].find_all("span")[3].text
   
    Rating = hotel_details[c].find_all("span")[2].text
    
    Type = hotel_details[c].find_all("span")[0].text
  
    #df=pd.DataFrame(Hotels, columns= ['Names', 'Locations', 'Recommendations', 'Ratings', 'Types' ])
    #df.to_csv (r'C:\Users\Sanjay\Desktop\export_dataframe.csv', index = True, header=True)
    print("Name: " + Name)
    print("Location: " + Location)
    print("Recommendation: " + Recommendation)
    print("rating: " + Rating)
    print("Type: " + Type)
    c=c+1
    
    f.write(Name + "," + Location.replace(",", "|") + "," + Recommendation + "," + Rating + "," + Type + "\n"  )
f.close()
# Out:
# rating: 4.6/5
# rating: 4.3/5
# rating: 4.6/5
# rating: 4.0/5
# rating: 4.4/5
# rating: 4.4/5
# rating: 4.3/5
# rating: 4.3/5
# rating: 4.5/5
# rating: 4.0/5

# %%
df=pd.read_csv('Hotels.csv')
df

# %%
df.index(len(maxcolumn)+1)
df.to_csv(r'C:\Users\Sanjay\Desktop\Hotels in Shimla.csv', index = True, header=True)
